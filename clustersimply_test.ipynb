# %%
import clustersimpy as cs  
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# ## Testing cs.measure

# %%
R_vec = np.array([0.8,0,0])
V_vec = np.array([0,16386,0])
x = [0.2, 9.55E-4, R_vec, V_vec]
Meas = cs.measure(x)
a = Meas.calculate_a()
e = Meas.calculate_e(a)

# %%
Meas.graph('3D',a,e)

# %% [markdown]
# ## Testing cs.gen_cluster

# %%
N = 1000             #(number of stars)
Rmax = 206264       #AU per parsec
q = 0.5
x = [Rmax,N,q]
R = cs.gen_cluster(x)
R.Gen_positions('Fractal',D=0.5) #Fractal does velocities too
#R.Gen_mass('KROUPA')
#R.Gen_velocities()
#print(R.V)
R.graph('3D')
R.graph('2D')
# Out:
# Number of Generations : 145
# Number of final stars : 1004
# Maximum Radius of clsuter: 206264
# Potential Energy (J) : 5.999985155920516e+40
# Median Mass (Sol Mass) 0.8572296528890977
# Total kineitc energy (with out added factor):  8.341007722330195e+38
# Velocity factor:  5.997231708107126
# mean v (m/s): 42.32291535990179
# median v (m/s): 0.54573655847502
# std v (m/s): 2424.9371657558336
# min v (m/s): -9428.115392455342
# max v (m/s): 6806.7062367697945

# %%
print(np.median(R.Mass))
print(np.mean(R.V))
# Out:
# 0.8572296528890977
# 42.32291535990179

# %%
theta = np.array([np.pi])
phi = np.array([0])
a = np.array([1]) 
e = np.array([0.0167])
M_star = np.array([1])
M_planet = np.array([5.9724E-6])

theta_1 = np.pi
phi = 0.9   
sig = 0.3
x = [theta,M_planet,M_star,phi,a,e,theta_1,phi,sig]
T = cs.get_planet(x)
T.calculate_params()
T.graph('2D')
T.graph('3D')

# %%
print(np.linalg.norm(T.V_vec))
# Out:
# 30972.326211944735

# %%
# testing genplanet_test!

# say we want a 4 planet system 
theta = np.array([np.pi/2, np.pi, 0, -np.pi/2])
M_star = 0.2
M_planet = np.array([9.55E-4,9.55E-4,9.55E-4,9.55E-4])
phi = np.array([0,0,0,0])
a = np.array([1,3,5,6]) #semi_major axis of the orbits in AU
e = np.array([0.4,0,0.6,0.8]) # all circular orbits!
theta_1 = 0.4
phi = 0.6
sig = 0.1
x = [theta,M_star,M_planet,phi,a,e,theta_1,phi,sig]
P = cs.get_planet(x)
P.calculate_params()

# %%
P.graph('2D')

# %%
P.graph('3D')
