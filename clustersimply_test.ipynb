# %%
import clustersimpy as cs  
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# ## Testing cs.measure

# %%
R_vec = np.array([0.8,0,0])
V_vec = np.array([0,16386,0])
x = [0.2, 9.55E-4, R_vec, V_vec]
Meas = cs.measure(x)
a = Meas.calculate_a()
e = Meas.calculate_e(a)
print(a,e)
# Out:
# 0.999872862387947 0.19989827697753537

# %%
Meas.graph('3D',a,e)

# %% [markdown]
# ## Testing cs.gen_cluster

# %%
N = 1000             #(number of stars)
Rmax = 206264       #AU per parsec
q = 0.5
sigma = 0.1 #sigma for Gausian noise
x = [Rmax,N,q,sigma]
Cluster = cs.gen_cluster(x)
Cluster.Gen_positions('Fractal',D=0.5) #Fractal does velocities too
#Cluster.Gen_mass('KROUPA')
#Cluster.Gen_velocities()
Cluster.graph('3D')
Cluster.graph('2D')
# Out:
# Number of Generations : 150
# Number of final stars : 1011
# Maximum Radius of clsuter: 206264
# Potential Energy (J) : 1.262099510483212e+40
# Median Mass (Sol Mass) 0.8688135358219018
# Total kineitc energy (with out added factor):  1.8837184886446605e+38
# Velocity factor:  5.787937077508394
# mean v (m/s): -108.57574299325378
# median v (m/s): -105.49843478322721
# std v (m/s): 1169.3427169432566
# min v (m/s): -3950.101986144
# max v (m/s): 3442.521114656218

# %%
print(np.mean(Cluster.V))
# Out:
# -108.57574299325378

# %%
theta = np.array([np.pi])
a = np.array([1]) 
e = np.array([0.0167])
M_star = np.array([1])
M_planet = np.array([5.9724E-6])

theta_1 = np.pi
phi = 0.9   
sig = 0.3
x = [theta,M_planet,M_star,phi,a,e,theta_1,phi,sig]
T = cs.get_planet(x)
T.calculate_params()
T.graph('2D')
T.graph('3D')

# %%
print(np.linalg.norm(T.V_vec))
# Out:
# 30972.326211944735

# %%
# testing genplanet_test!

# say we want a 4 planet system 
theta = np.array([np.pi/2, np.pi, 0, -np.pi/2])
M_star = 0.2
M_planet = np.array([9.55E-4,9.55E-4,9.55E-4,9.55E-4])
phi = np.array([0,0,0,0])
a = np.array([1,3,5,6]) #semi_major axis of the orbits in AU
e = np.array([0.4,0,0.6,0.8]) # all circular orbits!
theta_1 = 0.4
phi = 0.6
sig = 0.1
x = [theta,M_star,M_planet,phi,a,e,theta_1,phi,sig]
P = cs.get_planet(x)
P.calculate_params()

# %%
P.graph('2D')

# %%
P.graph('3D')
