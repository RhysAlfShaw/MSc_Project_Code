# %%
import clustersimpy as cs  
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# ## Testing cs.measure

# %%
R_vec = np.array([0.8,0,0])
V_vec = np.array([0,16386,0])
x = [0.2, 9.55E-4, R_vec, V_vec]
Meas = cs.measure(x)
a = Meas.calculate_a()
e = Meas.calculate_e(a)

# %%
Meas.graph('3D',a,e)

# %% [markdown]
# ## Testing cs.gen_cluster

# %%
N = 1000             #(number of stars)
Rmax = 206264       #AU per parsec
q = 0.5
sigma = 0.1 #sigma for Gausian noise
x = [Rmax,N,q,sigma]
R = cs.gen_cluster(x)
R.Gen_positions('Fractal',D=0.5) #Fractal does velocities too
#R.Gen_mass('KROUPA')
#R.Gen_velocities()
#print(R.V)
R.graph('3D')
R.graph('2D')
# Out:
# Number of Generations : 174
# Number of final stars : 1011
# Maximum Radius of clsuter: 206264
# Potential Energy (J) : 1.9090326275223993e+40
# Median Mass (Sol Mass) 0.8732091219529359
# Total kineitc energy (with out added factor):  2.1690774216968287e+38
# Velocity factor:  6.633674393155695
# mean v (m/s): 44.93540219039379
# median v (m/s): 41.38884677423339
# std v (m/s): 1378.2554229601421
# min v (m/s): -4077.5415156739227
# max v (m/s): 5206.084452684869

# %%
print(np.median(R.Mass))
print(np.mean(R.V))
# Out:
# 0.8732091219529359
# 44.93540219039379

# %%
theta = np.array([np.pi])
phi = np.array([0])
a = np.array([1]) 
e = np.array([0.0167])
M_star = np.array([1])
M_planet = np.array([5.9724E-6])

theta_1 = np.pi
phi = 0.9   
sig = 0.3
x = [theta,M_planet,M_star,phi,a,e,theta_1,phi,sig]
T = cs.get_planet(x)
T.calculate_params()
T.graph('2D')
T.graph('3D')

# %%
print(np.linalg.norm(T.V_vec))
# Out:
# 30972.326211944735

# %%
# testing genplanet_test!

# say we want a 4 planet system 
theta = np.array([np.pi/2, np.pi, 0, -np.pi/2])
M_star = 0.2
M_planet = np.array([9.55E-4,9.55E-4,9.55E-4,9.55E-4])
phi = np.array([0,0,0,0])
a = np.array([1,3,5,6]) #semi_major axis of the orbits in AU
e = np.array([0.4,0,0.6,0.8]) # all circular orbits!
theta_1 = 0.4
phi = 0.6
sig = 0.1
x = [theta,M_star,M_planet,phi,a,e,theta_1,phi,sig]
P = cs.get_planet(x)
P.calculate_params()

# %%
P.graph('2D')

# %%
P.graph('3D')
